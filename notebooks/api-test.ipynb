# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 10
#       7 SUPABASE_ANON_KEY = os.environ.get("SUPABASE_ANON_KEY", "paste-your-anon-key-here")
#       9 if SUPABASE_ANON_KEY in ("", "paste-your-anon-key-here"):
# ---> 10     raise RuntimeError(
#      11         "Set SUPABASE_ANON_KEY as an environment variable or replace the placeholder "
#      12         "value in this cell with your Supabase anon key before proceeding."
#      13     )
#      15 print(f"Function URL: {SUPABASE_FUNCTION_URL}")
#
# RuntimeError: Set SUPABASE_ANON_KEY as an environment variable or replace the placeholder value in this cell with your Supabase anon key before proceeding.
